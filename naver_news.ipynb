# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
from config import config_client_id, config_client_secret
import pandas as pd
import json
import re

client_id = config_client_id
client_secret = config_client_secret
query = urllib.parse.quote(input("검색어 입력: "))

idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns = ("Title", "Original Link", "Link", "Description", "Publication Date"))

for start_index in range(start, end, display):

    url = (
        "https://openapi.naver.com/v1/search/news?query=" + query +
        "&display=" + str(display) +
        "&start=" + str(start_index) +
        "&sort=" + sort
    ) # JSON 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            original_link = items[item_index]['originallink']
            link = items[item_index]['link']
            description = re.sub(remove_tag,'',items[item_index])['description']
            pub_date = re.sub(remove_tag,'',items[item_index]['pubDate'])
            news_df.loc[idx] = [title, original_link, link, description, pub_date]
            idx += 1
    else:
        print("Error Code:" + rescode)

news_df
# Out:
# {
# 	"lastBuildDate":"Thu, 27 Jun 2024 12:48:08 +0900",
# 	"total":276999,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>주가<\/b> 상승 삼천당제약, GLP-1 비만약 개발 추진",
# 			"originallink":"https:\/\/www.dailymedi.com\/news\/news_view.php?wr_id=913287",
# 			"link":"https:\/\/www.dailymedi.com\/news\/news_view.php?wr_id=913287",
# 			"description":"설비 확충 계획이 공개되는 등 개발이 구체화되자 삼천당제약 <b>주가<\/b>가 <b>급등<\/b>, 나흘만에 시가총액이 1조 원 이상 증가하기도 했다. 다만, 국내 다수 제약사가 GLP-1 계열 비만 치료제를 개발하고 있는 가운데 삼천당제약이... ",
# 			"pubDate":"Thu, 27 Jun 2024 12:18:00 +0900"
# 		},
# 		{
# 			"title":"[관심종목] 대한항공, 장중 7% 가까이 <b>급등<\/b>...미국 승인 청신호?",
# 			"originallink":"https:\/\/www.getnews.co.kr\/news\/articleView.html?idxno=681020",
# 			"link":"https:\/\/www.getnews.co.kr\/news\/articleView.html?idxno=681020",
# 			"description":"아시아나와의 기업결합이 미국 승인만 남겨 둔 가운데 대한항공 <b>주가<\/b>가 <b>급등<\/b>하고 있다. 대한항공과 아시아나 항공과의 기업결합은 미국 승인만을 남겨두고 있다. 사진=대한항공 27일 대한항공 <b>주가<\/b>는 소폭 하락... ",
# 			"pubDate":"Thu, 27 Jun 2024 12:02:00 +0900"
# 		},
# 		{
# 			"title":"삼성전자 웨이퍼 1조원 폐기?… 근거없는 지라시 확산에 ‘곤욕’",
# 			"originallink":"https:\/\/www.munhwa.com\/news\/view.html?no=2024062701071607080001",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/021\/0002645330?sid=101",
# 			"description":"재계 3위인 현대차그룹도 지난 14일에 정몽구 명예회장의 건강 이상설이 지라시로 퍼지면서 그룹 지배구조의 정점에 있는 현대모비스 등 일부 종목의 <b>주가<\/b>가 <b>급등<\/b>하는 소동도 빚어졌다. 현대모비스는 <b>주가<\/b> 변동 폭이... ",
# 			"pubDate":"Thu, 27 Jun 2024 11:45:00 +0900"
# 		},
# 		{
# 			"title":"근거없는 지라시에 대기업 <b>주가<\/b> 출렁…공정불량·구조조정에 건강 이상설까지",
# 			"originallink":"https:\/\/www.imaeil.com\/page\/view\/2024062711300726741",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/088\/0000888370?sid=101",
# 			"description":"지난 14일에는 정몽구 현대차그룹 명예회장의 건강 이상설이 퍼지면서 그룹 지배구조의 정점에 있는 현대모비스 등 일부 종목의 <b>주가<\/b>가 <b>급등<\/b>했다. 현대차그룹의 출자 구조는 '현대모비스→현대차→기아→현대모비스'로... ",
# 			"pubDate":"Thu, 27 Jun 2024 11:31:00 +0900"
# 		},
# 		{
# 			"title":"SK바이오사이언스 <b>주가<\/b> 장중 <b>급등<\/b>, 바이오의약품 위탁생산 글로벌기업 인수",
# 			"originallink":"https:\/\/www.businesspost.co.kr\/BP?command=article_view&num=356940",
# 			"link":"https:\/\/www.businesspost.co.kr\/BP?command=article_view&num=356940",
# 			"description":"SK바이오사이언스 <b>주가<\/b>가 장중 크게 오르고 있다. 바이오의약품 위탁생산 글로벌 기업을 인수하면서 투자심리가 개선된 것으로 보인다. 글로벌 위탁생산 기업 인수 소식에 27일 장중 SK바이오사이언스 <b>주가<\/b>가... ",
# 			"pubDate":"Thu, 27 Jun 2024 11:00:00 +0900"
# 		},
# 		{
# 			"title":"신작 출시 하루 만에...데브시스터즈 '장중 추락', 왜?",
# 			"originallink":"http:\/\/www.choicenews.co.kr\/news\/articleView.html?idxno=132192",
# 			"link":"http:\/\/www.choicenews.co.kr\/news\/articleView.html?idxno=132192",
# 			"description":"<b>주가 급등<\/b>에 따른 차익실현매물과 함께 기존 게임 업그레이드 논란, 게임업종의 장중 부진 등이 거론되는 가운데 이 같은 흐름이 나타나고 있다. 한국거래소에 따르면 오전 10시 21분 현재 데브시스터즈는 전일 대비 19.... ",
# 			"pubDate":"Thu, 27 Jun 2024 11:00:00 +0900"
# 		},
# 		{
# 			"title":"&quot;이러니 국장 떠나지&quot;…자진상폐 수순 신성통상에 개인들 분통 [김민아의 왜오...",
# 			"originallink":"https:\/\/biz.newdaily.co.kr\/site\/data\/html\/2024\/06\/27\/2024062700079.html",
# 			"link":"https:\/\/biz.newdaily.co.kr\/site\/data\/html\/2024\/06\/27\/2024062700079.html",
# 			"description":"2300원에 자진상폐를 하자 <b>주가<\/b>가 <b>급등<\/b>한 것입니다. <b>주가<\/b>가 단숨에 24% 치솟았으니 모르는 사람이야 부러워할 수 있겠지만 소액주주들은 애가 타는 상황입니다. 신성통상의 올해 3월 기준 회사의 주당순자산가치(BPS)는... ",
# 			"pubDate":"Thu, 27 Jun 2024 11:00:00 +0900"
# 		},
# 		{
# 			"title":"폭스바겐, 리비안에 7조원 투자 결정…<b>주가 급등<\/b> [당신이 잠든 사이]",
# 			"originallink":"https:\/\/www.fortunekorea.co.kr\/news\/articleView.html?idxno=39437",
# 			"link":"https:\/\/www.fortunekorea.co.kr\/news\/articleView.html?idxno=39437",
# 			"description":"이에 따라 리비안의 <b>주가<\/b>는 발표 이튿날인 26일, 거래 시작과 동시에 33% <b>급등<\/b>했다. 이번 투자 결정은 리비안이 직면하고 있는 막대한 손실 문제를 극복하고 전기 트럭 및 스포츠 유틸리티 차량(SUV)의 생산을... ",
# 			"pubDate":"Thu, 27 Jun 2024 10:56:00 +0900"
# 		},
# 		{
# 			"title":"[특징주] 아이오케이, 디모아 대상 유상증자 '上'",
# 			"originallink":"https:\/\/www.jeonmae.co.kr\/news\/articleView.html?idxno=1050774",
# 			"link":"https:\/\/www.jeonmae.co.kr\/news\/articleView.html?idxno=1050774",
# 			"description":"이는 아이오케이 <b>주가<\/b>가 이날 디모아 대상 유상증자를 결정했다는 소식에 <b>주가<\/b>가 <b>급등<\/b>한 것으로 보인다. 전날 아이오케이는 기타자금 조달을 위해 디모아를 대상으로 60억 원 규모의 제3자배정 유상증자를... ",
# 			"pubDate":"Thu, 27 Jun 2024 10:52:00 +0900"
# 		},
# 		{
# 			"title":"'용인 반도체 클러스터 전력난 해소 기대' 세명전기 <b>주가<\/b> 19%대 강세",
# 			"originallink":"https:\/\/www.gukjenews.com\/news\/articleView.html?idxno=3029696",
# 			"link":"https:\/\/www.gukjenews.com\/news\/articleView.html?idxno=3029696",
# 			"description":"세명전기 로고 세명전기 <b>주가<\/b>가 <b>급등<\/b> 중이다. 27일 오전 10시 30분 기준 세명전기는 전 거래일 대비 19.34% 오른 8700원에 거래되고 있다. 정부가 용인 반도체 클러스터의 전력 확보 문제를 해결하기 위해 지원에 나설... ",
# 			"pubDate":"Thu, 27 Jun 2024 10:44:00 +0900"
# 		}
# 	]
# }
